# %%
#calculadora de áreas-versión 1
#student: Axel André Alemán Sánchez

lado = float(input("ingrese el lado del cuadrado: "))
area = lado*lado
print("el area del cuadrado es",area)
# Out:
# ---------------------------------------------------------------------------
# StdinNotImplementedError                  Traceback (most recent call last)
# /tmp/ipykernel_16/3227234175.py in <cell line: 0>()
#       2 #student: Axel André Alemán Sánchez
#       3
# ----> 4 lado = float(input("ingrese el lado del cuadrado: "))
#       5 area = lado*lado
#       6 print("el area del cuadrado es",area)
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1172         """
#    1173         if not self._allow_stdin:
# -> 1174             raise StdinNotImplementedError(
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
#
# StdinNotImplementedError: raw_input was called, but this frontend does not support input requests.
